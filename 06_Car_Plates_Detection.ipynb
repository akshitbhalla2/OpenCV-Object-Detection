# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Open Image

# %%
img = cv2.imread("Images/car_plate.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# ### Detect Plate

# %%
def detect_plate(img):
    classifier = cv2.CascadeClassifier("./Haarcascades/haarcascade_plate_number.xml")
    measure = classifier.detectMultiScale(img)
    
    if measure is ():
        print("Not found!")
    
    else:
        for (x, y, w, h) in measure:
            cv2.rectangle(
                img,
                (x, y),
                (x+w, y+h),
                (255, 0, 0),
                10
            )
        
    return img

# %%
img = detect_plate(img)
plt.imshow(img)
